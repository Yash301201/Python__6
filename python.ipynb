# %%
n = int(input())
for i in range(n,0,-1):
    for j in range(1, i+1):
        print('*', end = " ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
s = 'python is easy'

count = 0

for ch in s:
    count = count + 1

rev = ""

for i in range(count - 1, -1, -1):
    rev = rev + s[i]

print(rev)
# Out:
# ysae si nohtyp

# %%
s = 'python is easy'

rev = ""

for ch in s:
    rev = ch + rev

print(rev)
# Out:
# ysae si nohtyp

# %%
n = int(input())
for i in range(1,n):
    for j in range(1, i+1):
        print('*',end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
